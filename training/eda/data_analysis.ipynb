# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)

# Style
sns.set(style="whitegrid")

# %%
df = pd.read_csv("../Bank Customer Churn Prediction.csv")
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
print("Shape:", df.shape)
print("\nColumns:\n", df.columns)
print("\nInfo:")
df.info()
# Out:
# Shape: (10000, 12)
#
# Columns:
#  Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='str')
#
# Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  str
#  3   gender            10000 non-null  str
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#         customer_id  credit_score           age        tenure        balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# ...

# %% [markdown]
# Numerical features are within logical ranges, with high variance in balance and salary indicating diverse customer behavior.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
for col in ['country','gender']:
    print(col, df[col].unique())
# Out:
# country <StringArray>
# ['France', 'Spain', 'Germany']
# Length: 3, dtype: str
# gender <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df.drop(["customer_id"], axis=1, inplace=True)

df.head()
# Out:
#    credit_score country  gender  age  tenure    balance  products_number  \
# 0           619  France  Female   42       2       0.00                1
# 1           608   Spain  Female   41       1   83807.86                1
# 2           502  France  Female   42       8  159660.80                3
# 3           699  France  Female   39       1       0.00                2
# 4           850   Spain  Female   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn
# 0            1              1         101348.88      1
# 1            0              1         112542.58      0
# 2            1              0         113931.57      1
# 3            0              0          93826.63      0
# 4            1              1          79084.10      0

# %%
df.isnull().sum()
# Out:
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %% [markdown]
# No Null Values Detected

# %%
categorical_cols = [
    'country',
    'gender',
    'credit_card',
    'active_member',
    'products_number'
]

for col in categorical_cols:
    
    plt.figure(figsize=(7,4))
    sns.countplot(x=col, data=df)
    
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# About 20% of customers have churned, showing moderate class imbalance that should be addressed in modeling.

# %%
num_cols = ['credit_score','age','tenure','balance','estimated_salary']

df[num_cols].hist(figsize=(12,8), bins=30)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df[num_cols])
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Dataset is clean, numerical features are logical, categorical features reveal behavioral insights, and churn is most influenced by age, engagement, and product ownership.
